# %%
#Add the directory
# %cd C:\Users\lab3\Desktop\Class_work\EE502\Features
# Out:
# C:\Users\lab3\Desktop\Class_work\EE502\Features

# %%
# importing required libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
pd.set_option('max_columns', None)

# %%
#loading the dataset
dataset = pd.read_excel("All_data.xlsx")
#Display forst rows
dataset.head()
# Out:
#    Participant    mean_ch1    mean_ch2   mean_ch3   mean_ch4  mean_ch5  \
# 0            2  -68.082074  -51.031745 -10.527269   2.315528 -0.019401
# 1            2  -77.006955  -59.638360 -13.851066   3.301459 -0.035965
# 2            2  -25.308444  -22.488517  -5.350912   1.393713 -0.001656
# 3            2  210.559327  158.651936  33.435422 -14.904149  0.010851
# 4            2  236.851464  180.828302  39.804005 -14.173984  0.008831
#
#     mean_ch6   mean_ch7   mean_ch8  Standard Deviation_ch1  \
# 0   6.305867  10.851360   3.708743               26.700413
# 1   7.818291  16.363432   4.544376               29.841539
# 2  -1.068934  11.045225  -0.096602               94.483683
# 3 -36.535425 -42.368458 -21.192230              229.042799
# 4 -34.439719 -53.176788 -23.603237              214.241661
#
#    Standard Deviation_ch2  Standard Deviation_ch3  Standard Deviation_ch4  \
# 0               19.154448                7.230746               11.790773
# 1               17.275745                9.699813                9.728939
# 2               63.699572               15.864481               13.953188
# 3              180.616440               37.946568               15.445216
# 4              178.227274               36.391211               24.416542
#
#    Standard Deviation_ch5  Standard Deviation_ch6  Standard Deviation_ch7  \
# 0                0.041478                7.465103               14.993082
# 1                0.032069               11.524404               17.149027
# 2                0.024227               20.975951               28.663477
# 3                0.001143               32.138648               47.593146
# 4                0.001226               33.780228               36.981993
#
#    Standard Deviation_ch8  Mean Absolute Value_ch1  Mean Absolute Value_ch2  \
# 0                9.253670                69.010046                51.307885
# 1               13.655198                77.006955                59.638360
# 2               17.998876                87.420957                62.331435
# 3               21.444003               244.799009               182.615013
# 4               18.163368               258.850078               209.177643
#
#    Mean Absolute Value_ch3  Mean Absolute Value_ch4  Mean Absolute Value_ch5  \
# 0                11.245078                 9.063941                 0.039334
# 1                15.250180                 7.521492                 0.040815
# 2                14.576736                10.525512                 0.018140
# 3                38.495411                18.134850                 0.010851
# 4                44.585342                25.321202                 0.008831
#
#    Mean Absolute Value_ch6  Mean Absolute Value_ch7  Mean Absolute Value_ch8  \
# 0                 7.897928                14.719392                 7.755028
# 1                10.426743                19.701463                11.240837
# 2                16.663652                27.583106                14.887007
# 3                41.315266                52.863073                25.904994
# 4                39.850289                53.309106                24.812276
#
#    Root Mean Square_ch1  Root Mean Square_ch2  Root Mean Square_ch3  \
# 0             73.091569             54.481159             12.754952
# 1             82.544055             62.071061             16.887619
# 2             97.451696             67.313932             16.682821
# 3            310.450446            239.862102             50.462277
# 4            318.800602            253.400342             53.834641
#
#    Root Mean Square_ch4  Root Mean Square_ch5  Root Mean Square_ch6  \
# 0             11.969620              0.045641              9.749149
# 1             10.237220              0.048101             13.888251
# 2             13.967417              0.024188             20.919875
# 3             21.419502              0.010910             48.575018
# 4             28.148497              0.008915             48.147084
#
#    Root Mean Square_ch7  Root Mean Square_ch8  Skewness_ch1  Skewness_ch2  \
# 0             18.459311              9.934795      1.137144      0.687373
# 1             23.654111             14.340011      0.120451     -0.169853
# 2             30.611621             17.927570      0.750860      0.844877
# 3             63.578430             30.088309      0.285561      0.435508
# 4             64.688361             29.738904      0.171987      0.027674
#
#    Skewness_ch3  Skewness_ch4  Skewness_ch5  Skewness_ch6  Skewness_ch7  \
# 0      0.382251     -0.038641     -0.086561      0.227213      0.231183
# 1      0.750072     -0.557858      0.338374      0.677953     -0.078828
# 2      0.020845     -1.223924     -1.623696     -0.411661     -0.767319
# 3      0.321223      0.362257     -0.039625      0.238837      0.041368
# 4     -0.091055      0.461004     -0.028744      0.116046     -0.392634
#
#    Skewness_ch8  kurtosis_ch1  kurtosis_ch2  kurtosis_ch3  kurtosis_ch4  \
# 0      0.388236      4.804805      3.900020      3.136779      2.776393
# 1      0.320648      2.825082      1.944017      3.717995      3.849482
# 2     -0.168173      2.192848      2.262129      1.685097      4.560927
# 3      0.397318      1.831627      1.837715      1.779427      2.084471
# 4      0.007991      1.907829      1.996487      1.913008      2.143605
#
#    kurtosis_ch5  kurtosis_ch6  kurtosis_ch7  kurtosis_ch8  Hactivity_ch1  \
# 0      1.344240      2.847963      2.674662      3.464439     712.912054
# 1      1.606047      2.957168      2.305422      3.074208     890.517466
# 2      4.179866      2.612254      2.379254      2.441453    8927.166270
# 3      1.810281      2.076817      2.078702      2.321601   52460.603626
# 4      1.747774      1.674753      1.905880      2.001772   45899.489425
#
#    Hactivity_ch2  Hactivity_ch3  Hactivity_ch4  Hactivity_ch5  Hactivity_ch6  \
# 0     366.892870      52.283692     139.022320       0.001720      55.727763
# 1     298.451365      94.086369      94.652251       0.001028     132.811898
# 2    4057.635513     251.681742     194.691458       0.000587     439.990532
# 3   32622.298523    1439.942042     238.554699       0.000001    1032.892681
# 4   31764.961252    1324.320238     596.167539       0.000002    1141.103786
#
#    Hactivity_ch7  Hactivity_ch7.1  HMobility_ch1  HMobility_ch2  \
# 0     224.792511        85.630410       0.215091       0.215091
# 1     294.089139       186.464441       0.189548       0.189548
# 2     821.594925       323.959535       0.184559       0.184559
# 3    2265.107554       459.845279       0.117528       0.117528
# 4    1367.667801       329.907929       0.088989       0.088989
#
#    HMobility_ch3  HMobility_ch4  HMobility_ch5  HMobility_ch6  HMobility_ch7  \
# 0       0.215091       0.215091       0.215091       0.215091       0.215091
# 1       0.189548       0.189548       0.189548       0.189548       0.189548
# 2       0.184559       0.184559       0.184559       0.184559       0.184559
# 3       0.117528       0.117528       0.117528       0.117528       0.117528
# 4       0.088989       0.088989       0.088989       0.088989       0.088989
#
#    HMobility_ch8  HComplexity_ch1  HComplexity_ch2  HComplexity_ch3  \
# 0       0.215091         5.823377         5.823377         5.823377
# 1       0.189548         6.410993         6.410993         6.410993
# 2       0.184559         6.757277         6.757277         6.757277
# 3       0.117528        10.865173        10.865173        10.865173
# 4       0.088989        12.585095        12.585095        12.585095
#
#    HComplexity_ch4  HComplexity_ch5  HComplexity_ch6  HComplexity_ch7  \
# 0         5.823377         5.823377         5.823377         5.823377
# 1         6.410993         6.410993         6.410993         6.410993
# 2         6.757277         6.757277         6.757277         6.757277
# 3        10.865173        10.865173        10.865173        10.865173
# 4        12.585095        12.585095        12.585095        12.585095
#
#    HComplexity_ch8  Shannon_Entropy_ch1  Shannon_Entropy_ch2  \
# 0         5.823377        -9.517344e+06        -9.517344e+06
# 1         6.410993        -1.294499e+07        -1.294499e+07
# 2         6.757277        -1.814937e+07        -1.814937e+07
# 3        10.865173        -2.445025e+08        -2.445025e+08
# 4        12.585095        -2.619810e+08        -2.619810e+08
#
#    Shannon_Entropy_ch3  Shannon_Entropy_ch4  Shannon_Entropy_ch5  \
# 0        -9.517344e+06        -9.517344e+06        -9.517344e+06
# 1        -1.294499e+07        -1.294499e+07        -1.294499e+07
# 2        -1.814937e+07        -1.814937e+07        -1.814937e+07
# 3        -2.445025e+08        -2.445025e+08        -2.445025e+08
# 4        -2.619810e+08        -2.619810e+08        -2.619810e+08
#
#    Shannon_Entropy_ch6  Shannon_Entropy_ch7  Shannon_Entropy_ch8  \
# 0        -9.517344e+06        -9.517344e+06        -9.517344e+06
# 1        -1.294499e+07        -1.294499e+07        -1.294499e+07
# 2        -1.814937e+07        -1.814937e+07        -1.814937e+07
# 3        -2.445025e+08        -2.445025e+08        -2.445025e+08
# 4        -2.619810e+08        -2.619810e+08        -2.619810e+08
#
#    Power Spectral Density_ch1  Power Spectral Density_ch2  \
# 0                 4588.751100                 1706.750311
# 1                 2155.936716                 1489.069802
# 2                 3155.364595                 1431.098870
# 3                15975.093578                11641.262386
# 4                38706.466667                39402.082756
#
#    Power Spectral Density_ch3  Power Spectral Density_ch4  \
# 0                   51.384037                   45.251309
# 1                   90.075615                   33.100494
# 2                   87.904151                   61.617285
# 3                  828.512057                  144.906923
# 4                  915.369729                  250.254071
#
#    Power Spectral Density_ch5  Power Spectral Density_ch6  \
# 0                1.758736e-03                   30.019523
# 1                7.668241e-04                   60.920785
# 2                1.653921e-04                  138.225621
# 3                1.021009e-06                  816.783336
# 4                5.530137e-07                  762.465900
#
#    Power Spectral Density_ch7  Power Spectral Density_ch8
# 0                  107.622079                   31.173689
# 1                  176.719171                   64.948531
# 2                  295.970483                  101.511013
# 3                 1435.397809                  286.066135
# 4                 1378.583475                  279.760111

# %%
# distributing the dataset into two components X and Y
X = dataset.iloc[:, 1:89] #Independent variables
y = dataset.iloc[:, 0] #Dependent variable

# %%
# Split the data into Training set and Testing set
from sklearn.model_selection import train_test_split
  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0) #80% train and 20% test

# %%
#performing z-normalization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
  
X_train = sc.fit_transform(X_train) #normalize training data
X_test = sc.transform(X_test) #normalize test data

# %%
#as normalization creates an output's array,convert an array to dataframe
X_train = pd.DataFrame(X_train, columns=X.columns)
X_test = pd.DataFrame(X_test, columns=X.columns)

# %%
#Print the correlation matrix

#cor = X_train_df.corr() #Correction matrix


# Create correlation matrix
corr_matrix = X_train.corr().abs()
# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# Drop features 
X_train.drop(to_drop, axis=1, inplace=True)
X_test.drop(to_drop,axis=1,inplace=True)
#plt.figure(figsize=(20,10))
#sns.heatmap(corr_matrix, cmap=plt.cm.CMRmap_r,annot=True)
#plt.show()  
#print(cor)
# Out:
# C:\Users\lab3\AppData\Local\Temp/ipykernel_26680/2084015720.py:9: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# %%
to_drop
# Out:
# ['Mean Absolute Value_ch1',
#  'Mean Absolute Value_ch2',
#  'Mean Absolute Value_ch3',
#  'Mean Absolute Value_ch4',
#  'Mean Absolute Value_ch5',
#  'Mean Absolute Value_ch6',
#  'Mean Absolute Value_ch7',
#  'Mean Absolute Value_ch8',
#  'Root Mean Square_ch1',
#  'Root Mean Square_ch2',
#  'Root Mean Square_ch3',
#  'Root Mean Square_ch4',
#  'Root Mean Square_ch5',
#  'Root Mean Square_ch6',
#  'Root Mean Square_ch7',
#  'Root Mean Square_ch8',
#  'Hactivity_ch2',
#  'HMobility_ch2',
#  'HMobility_ch3',
#  'HMobility_ch4',
#  'HMobility_ch5',
#  'HMobility_ch6',
#  'HMobility_ch7',
#  'HMobility_ch8',
#  'HComplexity_ch2',
#  'HComplexity_ch3',
#  'HComplexity_ch4',
#  'HComplexity_ch5',
#  'HComplexity_ch6',
#  'HComplexity_ch7',
#  'HComplexity_ch8',
#  'Shannon_Entropy_ch1',
#  'Shannon_Entropy_ch2',
#  'Shannon_Entropy_ch3',
#  'Shannon_Entropy_ch4',
#  'Shannon_Entropy_ch5',
#  'Shannon_Entropy_ch6',
#  'Shannon_Entropy_ch7',
#  'Shannon_Entropy_ch8',
#  'Power Spectral Density_ch2',
#  'Power Spectral Density_ch3',
#  'Power Spectral Density_ch4',
#  'Power Spectral Density_ch5',
#  'Power Spectral Density_ch6',
#  'Power Spectral Density_ch7',
#  'Power Spectral Density_ch8']

# %%
#as per the correlation matrix the features seems to be correlated so applying PCA 
from sklearn.decomposition import PCA

pca = PCA(.90) #PCA with 90% variance
X_train = pca.fit_transform(X_train) #PCA on train data
X_test = pca.transform(X_test)#PCA on test data

# %%
len(X_train)
# Out:
# 6067

# %%
#for 90% variance we got 19 PCs and below ouput explains contribution of each PC
pca.explained_variance_
# Out:
# array([8.67044874, 5.4935877 , 3.68775222, 2.30346887, 2.16319847,
#        1.60914648, 1.37581296, 1.24663781, 1.15989849, 1.0956048 ,
#        0.9666183 , 0.91451954, 0.84007318, 0.7833378 , 0.76605978,
#        0.73415131, 0.71528138, 0.685587  , 0.65710504, 0.64508347,
#        0.60175648, 0.57360632, 0.54668641])

# %% [markdown]
# Linear Support Vector Machine Model

# %%
#Import svm model
from sklearn import svm
from sklearn import metrics

#Create a svm Classifier
model_lin = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
model_lin.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = model_lin.predict(X_test)

# %%
#Print the classification report
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.82      0.88      0.85       136
#            3       0.95      0.89      0.92       116
#            4       0.82      0.80      0.81       129
#            6       0.85      0.91      0.88       129
#            7       0.94      0.94      0.94       129
#            8       0.71      0.74      0.72       124
#            9       0.76      0.88      0.81       120
#           10       0.65      0.70      0.67       125
#           11       0.74      0.69      0.71       129
#           12       0.65      0.49      0.56       118
#           13       0.65      0.65      0.65       124
#           14       0.92      0.89      0.90       138
#
#     accuracy                           0.79      1517
#    macro avg       0.79      0.79      0.79      1517
# weighted avg       0.79      0.79      0.79      1517

# %%
# Model Accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# Model Precision
print("Precision:",metrics.precision_score(y_test, y_pred,average='macro'))

# Model Recall
print("Recall:",metrics.recall_score(y_test, y_pred,average='macro'))
# Out:
# Accuracy: 0.7897165458141068
# Precision: 0.7874806490720475
# Recall: 0.7870992427970451

# %% [markdown]
# SVM hyper parameter tuning with Grid Search

# %%
from sklearn.model_selection import GridSearchCV
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf','linear']} 
  
grid = GridSearchCV(svm.SVC(), param_grid, refit = True, verbose = 3,cv=12) #Grid model definition
  
grid.fit(X_train, y_train) #fit the model

# %%
# print best parameter after tuning
print(grid.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)

# %%
#Prediction on grid search model
grid_predictions = grid.predict(X_test)
  
# print classification report
print(metrics.classification_report(y_test, grid_predictions))

# %% [markdown]
# Support vector machine model with best parameters suggested by grid search

# %%
#Model with best hyperparameters suggested by gridsearch
model_hyp = svm.SVC(kernel='rbf', C=100, gamma=0.01)

#Train the model using the training sets
model_hyp.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = model_hyp.predict(X_test)

# %%
# Model Accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# Model Precision
print("Precision:",metrics.precision_score(y_test, y_pred,average='macro'))

# Model Recall
print("Recall:",metrics.recall_score(y_test, y_pred,average='macro'))
# Out:
# Accuracy: 0.8694792353328938
# Precision: 0.8684499764222281
# Recall: 0.867821498903217
